# %%
# !pip install geopy
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors


#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /Users/jiawen/anaconda3/lib/python3.7/site-packages (1.20.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/jiawen/anaconda3/lib/python3.7/site-packages (from geopy) (1.49)
# Libraries imported.

# %%
df = pd.read_csv('./to_venues')
df.shape
df.head()
# Out:
# (2250, 7)

# %%
# address = 'Toronto, ON'

# geolocator = Nominatim(user_agent="to_explorer")
# location = geolocator.geocode(address)
# latitude = location.latitude
# longitude = location.longitude
# print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
# map_to = folium.Map(location=[latitude, longitude], zoom_start=10)

# # add markers to map
# for lat, lng, neighborhood in zip(df['Venue Latitude'], df['Venue Longitude'], df['Neighborhood']):
#     label = '{}'.format(neighborhood)
#     label = folium.Popup(label, parse_html=True)
#     folium.CircleMarker(
#         [lat, lng],
#         radius=5,
#         popup=label,
#         color='blue',
#         fill=True,
#         fill_color='#3186cc',
#         fill_opacity=0.7,
#         parse_html=False).add_to(map_to)  
    
# map_to
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-de5642966c99> in <module>
#      13         fill_color='#3186cc',
#      14         fill_opacity=0.7,
# ---> 15         parse_html=False).add_to(map_to)
#      16
#      17 map_to
#
# ~/anaconda3/lib/python3.7/site-packages/folium/features.py in __init__(self, location, radius, popup, **kw)
#     882                 ).addTo({{this._parent.get_name()}});
#     883             {% endmacro %}
# --> 884             """)
#     885
#     886
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/environment.py in __new__(cls, source, block_start_string, block_end_string, variable_start_string, variable_end_string, comment_start_string, comment_end_string, line_statement_prefix, line_comment_prefix, trim_blocks, lstrip_blocks, newline_sequence, keep_trailing_newline, extensions, optimized, undefined, finalize, autoescape, enable_async)
#     943             frozenset(extensions), optimized, undefined, finalize, autoescape,
#     944             None, 0, False, None, enable_async)
# --> 945         return env.from_string(source, template_class=cls)
#     946
#     947     @classmethod
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/environment.py in from_string(self, source, globals, template_class)
#     878         globals = self.make_globals(globals)
#     879         cls = template_class or self.template_class
# --> 880         return cls.from_code(self, self.compile(source), globals, None)
#     881
#     882     def make_globals(self, d):
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/environment.py in compile(self, source, name, filename, raw, defer_init)
#     577             if isinstance(source, string_types):
#     578                 source_hint = source
# --> 579                 source = self._parse(source, name, filename)
#     580             source = self._generate(source, name, filename,
#     581                                     defer_init=defer_init)
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/environment.py in _parse(self, source, name, filename)
#     495     def _parse(self, source, name, filename):
#     496         """Internal parsing function used by `parse` and `compile`."""
# --> 497         return Parser(self, source, name, encode_filename(filename)).parse()
#     498
#     499     def lex(self, source, name=None, filename=None):
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse(self)
#     899     def parse(self):
#     900         """Parse the whole template into a `Template` node."""
# --> 901         result = nodes.Template(self.subparse(), lineno=1)
#     902         result.set_environment(self.environment)
#     903         return result
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in subparse(self, end_tokens)
#     881                        self.stream.current.test_any(*end_tokens):
#     882                         return body
# --> 883                     rv = self.parse_statement()
#     884                     if isinstance(rv, list):
#     885                         body.extend(rv)
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_statement(self)
#     128         try:
#     129             if token.value in _statement_keywords:
# --> 130                 return getattr(self, 'parse_' + self.stream.current.value)()
#     131             if token.value == 'call':
#     132                 return self.parse_call_block()
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_macro(self)
#     382         self.parse_signature(node)
#     383         node.body = self.parse_statements(('name:endmacro',),
# --> 384                                           drop_needle=True)
#     385         return node
#     386
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_statements(self, end_tokens, drop_needle)
#     163         # by adding some sort of end of statement token and parsing those here.
#     164         self.stream.expect('block_end')
# --> 165         result = self.subparse(end_tokens)
#     166
#     167         # we reached the end of the template too early, the subparser
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in subparse(self, end_tokens)
#     873                 elif token.type == 'variable_begin':
#     874                     next(self.stream)
# --> 875                     add_data(self.parse_tuple(with_condexpr=True))
#     876                     self.stream.expect('variable_end')
#     877                 elif token.type == 'block_begin':
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_tuple(self, simplified, with_condexpr, extra_end_rules, explicit_parentheses)
#     618             if self.is_tuple_end(extra_end_rules):
#     619                 break
# --> 620             args.append(parse())
#     621             if self.stream.current.type == 'comma':
#     622                 is_tuple = True
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_expression(self, with_condexpr)
#     430         """
#     431         if with_condexpr:
# --> 432             return self.parse_condexpr()
#     433         return self.parse_or()
#     434
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_condexpr(self)
#     435     def parse_condexpr(self):
#     436         lineno = self.stream.current.lineno
# --> 437         expr1 = self.parse_or()
#     438         while self.stream.skip_if('name:if'):
#     439             expr2 = self.parse_or()
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_or(self)
#     448     def parse_or(self):
#     449         lineno = self.stream.current.lineno
# --> 450         left = self.parse_and()
#     451         while self.stream.skip_if('name:or'):
#     452             right = self.parse_and()
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_and(self)
#     457     def parse_and(self):
#     458         lineno = self.stream.current.lineno
# --> 459         left = self.parse_not()
#     460         while self.stream.skip_if('name:and'):
#     461             right = self.parse_not()
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_not(self)
#     468             lineno = next(self.stream).lineno
#     469             return nodes.Not(self.parse_not(), lineno=lineno)
# --> 470         return self.parse_compare()
#     471
#     472     def parse_compare(self):
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_compare(self)
#     472     def parse_compare(self):
#     473         lineno = self.stream.current.lineno
# --> 474         expr = self.parse_math1()
#     475         ops = []
#     476         while 1:
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_math1(self)
#     494     def parse_math1(self):
#     495         lineno = self.stream.current.lineno
# --> 496         left = self.parse_concat()
#     497         while self.stream.current.type in ('add', 'sub'):
#     498             cls = _math_nodes[self.stream.current.type]
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_concat(self)
#     505     def parse_concat(self):
#     506         lineno = self.stream.current.lineno
# --> 507         args = [self.parse_math2()]
#     508         while self.stream.current.type == 'tilde':
#     509             next(self.stream)
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_math2(self)
#     515     def parse_math2(self):
#     516         lineno = self.stream.current.lineno
# --> 517         left = self.parse_pow()
#     518         while self.stream.current.type in ('mul', 'div', 'floordiv', 'mod'):
#     519             cls = _math_nodes[self.stream.current.type]
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_pow(self)
#     526     def parse_pow(self):
#     527         lineno = self.stream.current.lineno
# --> 528         left = self.parse_unary()
#     529         while self.stream.current.type == 'pow':
#     530             next(self.stream)
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_unary(self, with_filter)
#     545         else:
#     546             node = self.parse_primary()
# --> 547         node = self.parse_postfix(node)
#     548         if with_filter:
#     549             node = self.parse_filter_expr(node)
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_postfix(self, node)
#     670             token_type = self.stream.current.type
#     671             if token_type == 'dot' or token_type == 'lbracket':
# --> 672                 node = self.parse_subscript(node)
#     673             # calls are valid both after postfix expressions (getattr
#     674             # and getitem) as well as filters and tests
#
# ~/anaconda3/lib/python3.7/site-packages/jinja2/parser.py in parse_subscript(self, node)
#     717             else:
#     718                 arg = nodes.Tuple(args, 'load', lineno=token.lineno)
# --> 719             return nodes.Getitem(node, arg, 'load', lineno=token.lineno)
#     720         self.fail('expected subscript expression', self.lineno)
#     721
#
# KeyboardInterrupt:
